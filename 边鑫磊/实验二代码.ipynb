# %%
import pandas as pd
from pandas import DataFrame
import numpy as np

data = pd.read_csv(r"C:\Users\边鑫磊\Desktop\Pokemon.csv", encoding='ISO-8859-1')
data
# Out:
#              #                   Name     Type 1     Type 2      Total  \
# 0            1              Bulbasaur      Grass     Poison        318
# 1            2                Ivysaur      Grass     Poison        405
# 2            3               Venusaur      Grass     Poison        525
# 3            3  VenusaurMega Venusaur      Grass     Poison        625
# 4            4             Charmander       Fire        NaN        309
# ..         ...                    ...        ...        ...        ...
# 805        721              Volcanion       Fire      Water        600
# 806  undefined              undefined  undefined  undefined  undefined
# 807  undefined              undefined  undefined  undefined  undefined
# 808        NaN                    NaN        NaN        NaN        NaN
# 809        NaN                    NaN        NaN        NaN        NaN
#
#             HP     Attack    Defense    Sp. Atk    Sp. Def      Speed  \
# 0           45         49         49         65         65         45
# 1           60         62         63         80         80         60
# 2           80         82         83        100        100         80
# 3           80        100        123        122        120         80
# 4           39         52         43         60         50         65
# ..         ...        ...        ...        ...        ...        ...
# 805         80        110        120        130         90         70
# 806  undefined  undefined  undefined  undefined  undefined  undefined
# 807  undefined  undefined  undefined  undefined  undefined  undefined
# 808        NaN        NaN        NaN        NaN        NaN        NaN
# 809        NaN        NaN        NaN        NaN        NaN        NaN
#
#     Generation  Legendary
# 0            1      FALSE
# 1            1      FALSE
# 2            1      FALSE
# 3            1      FALSE
# 4            1      FALSE
# ..         ...        ...
# 805          6       TRUE
# 806  undefined  undefined
# 807  undefined  undefined
# 808        NaN
# 809        NaN
#
# [810 rows x 13 columns]

# %%
data = data.iloc[:-4]
data
# Out:
#        #                   Name   Type 1  Type 2 Total  HP Attack Defense  \
# 0      1              Bulbasaur    Grass  Poison   318  45     49      49
# 1      2                Ivysaur    Grass  Poison   405  60     62      63
# 2      3               Venusaur    Grass  Poison   525  80     82      83
# 3      3  VenusaurMega Venusaur    Grass  Poison   625  80    100     123
# 4      4             Charmander     Fire     NaN   309  39     52      43
# ..   ...                    ...      ...     ...   ...  ..    ...     ...
# 801  719                Diancie     Rock   Fairy   600  50    100     150
# 802  719    DiancieMega Diancie     Rock   Fairy   700  50    160     110
# 803  720    HoopaHoopa Confined  Psychic   Ghost   600  80    110      60
# 804  720     HoopaHoopa Unbound  Psychic    Dark   680  80    160      60
# 805  721              Volcanion     Fire   Water   600  80    110     120
#
#     Sp. Atk Sp. Def Speed Generation Legendary
# 0        65      65    45          1     FALSE
# 1        80      80    60          1     FALSE
# 2       100     100    80          1     FALSE
# 3       122     120    80          1     FALSE
# 4        60      50    65          1     FALSE
# ..      ...     ...   ...        ...       ...
# 801     100     150    50          6      TRUE
# 802     160     110   110          6      TRUE
# 803     150     130    70          6      TRUE
# 804     170     130    80          6      TRUE
# 805     130      90    70          6      TRUE
#
# [806 rows x 13 columns]

# %%
data["Type 2"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Type 2'>

# %%
data=data[data["Type 2"]!='273']
data
# Out:
#        #                   Name   Type 1  Type 2 Total  HP Attack Defense  \
# 0      1              Bulbasaur    Grass  Poison   318  45     49      49
# 1      2                Ivysaur    Grass  Poison   405  60     62      63
# 2      3               Venusaur    Grass  Poison   525  80     82      83
# 3      3  VenusaurMega Venusaur    Grass  Poison   625  80    100     123
# 4      4             Charmander     Fire     NaN   309  39     52      43
# ..   ...                    ...      ...     ...   ...  ..    ...     ...
# 801  719                Diancie     Rock   Fairy   600  50    100     150
# 802  719    DiancieMega Diancie     Rock   Fairy   700  50    160     110
# 803  720    HoopaHoopa Confined  Psychic   Ghost   600  80    110      60
# 804  720     HoopaHoopa Unbound  Psychic    Dark   680  80    160      60
# 805  721              Volcanion     Fire   Water   600  80    110     120
#
#     Sp. Atk Sp. Def Speed Generation Legendary
# 0        65      65    45          1     FALSE
# 1        80      80    60          1     FALSE
# 2       100     100    80          1     FALSE
# 3       122     120    80          1     FALSE
# 4        60      50    65          1     FALSE
# ..      ...     ...   ...        ...       ...
# 801     100     150    50          6      TRUE
# 802     160     110   110          6      TRUE
# 803     150     130    70          6      TRUE
# 804     170     130    80          6      TRUE
# 805     130      90    70          6      TRUE
#
# [805 rows x 13 columns]

# %%
data[data.duplicated()]
# Out:
#        #       Name  Type 1  Type 2 Total  HP Attack Defense Sp. Atk Sp. Def  \
# 15    11    Metapod     Bug     NaN   205  50     20      55      25      25
# 23    17  Pidgeotto  Normal  Flying   349  63     60      55      50      50
# 185  168    Ariados     Bug  Poison   390  70     90      70      60      60
# 186  168    Ariados     Bug  Poison   390  70     90      70      60      60
# 187  168    Ariados     Bug  Poison   390  70     90      70      60      60
#
#     Speed Generation Legendary
# 15     30          1     FALSE
# 23     71          1     FALSE
# 185    40          2     FALSE
# 186    40          2     FALSE
# 187    40          2     FALSE

# %%
data=data.copy()
data.drop_duplicates(inplace=True)
data
# Out:
#        #                   Name   Type 1  Type 2 Total  HP Attack Defense  \
# 0      1              Bulbasaur    Grass  Poison   318  45   49.0      49
# 1      2                Ivysaur    Grass  Poison   405  60   62.0      63
# 2      3               Venusaur    Grass  Poison   525  80   82.0      83
# 3      3  VenusaurMega Venusaur    Grass  Poison   625  80  100.0     123
# 4      4             Charmander     Fire     NaN   309  39   52.0      43
# ..   ...                    ...      ...     ...   ...  ..    ...     ...
# 801  719                Diancie     Rock   Fairy   600  50  100.0     150
# 802  719    DiancieMega Diancie     Rock   Fairy   700  50  160.0     110
# 803  720    HoopaHoopa Confined  Psychic   Ghost   600  80  110.0      60
# 804  720     HoopaHoopa Unbound  Psychic    Dark   680  80  160.0      60
# 805  721              Volcanion     Fire   Water   600  80  110.0     120
#
#     Sp. Atk Sp. Def Speed Generation Legendary
# 0        65      65    45          1     FALSE
# 1        80      80    60          1     FALSE
# 2       100     100    80          1     FALSE
# 3       122     120    80          1     FALSE
# 4        60      50    65          1     FALSE
# ..      ...     ...   ...        ...       ...
# 801     100     150    50          6      TRUE
# 802     160     110   110          6      TRUE
# 803     150     130    70          6      TRUE
# 804     170     130    80          6      TRUE
# 805     130      90    70          6      TRUE
#
# [800 rows x 13 columns]

# %%
import matplotlib.pyplot as plt
data.iloc[:, 6] = pd.to_numeric(data.iloc[:, 6], errors='coerce')
plt.scatter(range(0,data.shape[0]),data.iloc[:,6])

# %%
data_clean = data[data['Attack'] < 800].copy()
data_clean
# Out:
#        #                   Name   Type 1  Type 2 Total  HP Attack Defense  \
# 0      1              Bulbasaur    Grass  Poison   318  45   49.0      49
# 1      2                Ivysaur    Grass  Poison   405  60   62.0      63
# 2      3               Venusaur    Grass  Poison   525  80   82.0      83
# 3      3  VenusaurMega Venusaur    Grass  Poison   625  80  100.0     123
# 4      4             Charmander     Fire     NaN   309  39   52.0      43
# ..   ...                    ...      ...     ...   ...  ..    ...     ...
# 801  719                Diancie     Rock   Fairy   600  50  100.0     150
# 802  719    DiancieMega Diancie     Rock   Fairy   700  50  160.0     110
# 803  720    HoopaHoopa Confined  Psychic   Ghost   600  80  110.0      60
# 804  720     HoopaHoopa Unbound  Psychic    Dark   680  80  160.0      60
# 805  721              Volcanion     Fire   Water   600  80  110.0     120
#
#     Sp. Atk Sp. Def Speed Generation Legendary
# 0        65      65    45          1     FALSE
# 1        80      80    60          1     FALSE
# 2       100     100    80          1     FALSE
# 3       122     120    80          1     FALSE
# 4        60      50    65          1     FALSE
# ..      ...     ...   ...        ...       ...
# 801     100     150    50          6      TRUE
# 802     160     110   110          6      TRUE
# 803     150     130    70          6      TRUE
# 804     170     130    80          6      TRUE
# 805     130      90    70          6      TRUE
#
# [797 rows x 13 columns]

# %%
data_clean.iloc[10:30]
# Out:
#      #                     Name    Type 1  Type 2 Total   HP Attack Defense  \
# 11   9                Blastoise     Water     NaN   530   79   83.0     100
# 12   9  BlastoiseMega Blastoise     Water     NaN   630   79  103.0     120
# 13  10                 Caterpie       Bug     NaN   195   45   30.0      35
# 14  11                  Metapod       Bug     NaN   205   50   20.0      55
# 16  12               Butterfree       Bug  Flying   395   60   45.0      50
# 17  13                   Weedle       Bug  Poison   195  NaN   35.0      30
# 18  14                   Kakuna       Bug  Poison   205   45   25.0      50
# 19  15                 Beedrill       Bug  Poison   395   65   90.0      40
# 20  15    BeedrillMega Beedrill       Bug  Poison   495   65  150.0      40
# 21  17                Pidgeotto    Normal  Flying   349   63   60.0      55
# 22  16                   Pidgey    Normal  Flying   251   40   45.0      40
# 24  18                  Pidgeot    Normal  Flying   479   83   80.0      75
# 25  18      PidgeotMega Pidgeot    Normal  Flying   579   83   80.0      80
# 26  19                  Rattata    Normal     NaN   253   30   56.0      35
# 27  20                 Raticate    Normal     NaN   413   55   81.0      60
# 28  21                  Spearow    Normal  Flying   262   40   60.0      30
# 29  22                   Fearow    Normal  Flying   442   65   90.0      65
# 30  23                    Ekans    Poison     NaN   288   35   60.0      44
# 31  24                    Arbok    Poison     NaN   438   60   85.0      69
# 32  25                  Pikachu  Electric     NaN   320   35   55.0      40
#
#    Sp. Atk Sp. Def Speed Generation Legendary
# 11      85     105    78      FALSE         1
# 12     135     115    78          1     FALSE
# 13      20      20    45          1     FALSE
# 14      25      25    30          1     FALSE
# 16      90      80    70          1     FALSE
# 17      20      20    50          1     FALSE
# 18      25      25    35          1     FALSE
# 19      45      80    75          1     FALSE
# 20      15      80   145          1     FALSE
# 21      50      50    71          1     FALSE
# 22      35      35    56          1     FALSE
# 24      70      70   101          1     FALSE
# 25     135      80   121          1     FALSE
# 26      25      35    72          1     FALSE
# 27      50      70    97          1     FALSE
# 28      31      31    70          1     FALSE
# 29      61      61   100          1     FALSE
# 30      40      54    55          1     FALSE
# 31      65      79    80          1     FALSE
# 32      50      50    90      FALSE         0

# %%
df1=data_clean.copy()
last_two_cols = df.columns[-2:]

row11_col1 = df1.loc[11, last_two_cols[0]]
row11_col2 = df1.loc[11, last_two_cols[1]]
df1.loc[11, last_two_cols[0]] = row11_col2
df1.loc[11, last_two_cols[1]] = row11_col1

row30_col1 = df1.loc[32, last_two_cols[0]]
row30_col2 = df1.loc[32, last_two_cols[1]]
df1.loc[32, last_two_cols[0]] = row30_col2
df1.loc[32, last_two_cols[1]] = row30_col1

df1.iloc[10:30]
# Out:
#      #                     Name    Type 1  Type 2 Total   HP Attack Defense  \
# 11   9                Blastoise     Water     NaN   530   79   83.0     100
# 12   9  BlastoiseMega Blastoise     Water     NaN   630   79  103.0     120
# 13  10                 Caterpie       Bug     NaN   195   45   30.0      35
# 14  11                  Metapod       Bug     NaN   205   50   20.0      55
# 16  12               Butterfree       Bug  Flying   395   60   45.0      50
# 17  13                   Weedle       Bug  Poison   195  NaN   35.0      30
# 18  14                   Kakuna       Bug  Poison   205   45   25.0      50
# 19  15                 Beedrill       Bug  Poison   395   65   90.0      40
# 20  15    BeedrillMega Beedrill       Bug  Poison   495   65  150.0      40
# 21  17                Pidgeotto    Normal  Flying   349   63   60.0      55
# 22  16                   Pidgey    Normal  Flying   251   40   45.0      40
# 24  18                  Pidgeot    Normal  Flying   479   83   80.0      75
# 25  18      PidgeotMega Pidgeot    Normal  Flying   579   83   80.0      80
# 26  19                  Rattata    Normal     NaN   253   30   56.0      35
# 27  20                 Raticate    Normal     NaN   413   55   81.0      60
# 28  21                  Spearow    Normal  Flying   262   40   60.0      30
# 29  22                   Fearow    Normal  Flying   442   65   90.0      65
# 30  23                    Ekans    Poison     NaN   288   35   60.0      44
# 31  24                    Arbok    Poison     NaN   438   60   85.0      69
# 32  25                  Pikachu  Electric     NaN   320   35   55.0      40
#
#    Sp. Atk Sp. Def Speed Generation Legendary
# 11      85     105    78          1     FALSE
# 12     135     115    78          1     FALSE
# 13      20      20    45          1     FALSE
# 14      25      25    30          1     FALSE
# 16      90      80    70          1     FALSE
# 17      20      20    50          1     FALSE
# 18      25      25    35          1     FALSE
# 19      45      80    75          1     FALSE
# 20      15      80   145          1     FALSE
# 21      50      50    71          1     FALSE
# 22      35      35    56          1     FALSE
# 24      70      70   101          1     FALSE
# 25     135      80   121          1     FALSE
# 26      25      35    72          1     FALSE
# 27      50      70    97          1     FALSE
# 28      31      31    70          1     FALSE
# 29      61      61   100          1     FALSE
# 30      40      54    55          1     FALSE
# 31      65      79    80          1     FALSE
# 32      50      50    90          0     FALSE
